# %% [markdown]
# # Garden menu
# Inspect focused cells, **emphasis**, and `inline code`; notebook chrome is a workbench feature.

# %%
# Hover describe or request signature help with a Python language server.
def describe(title: str, quantity: int = 1) -> str:
    return f"{title}: {quantity} portions"

specials = [{"title": "Soup", "price": 12.5, "tags": ["vegan"]}]
describe(specials[0]["title"], 2)
